# %% [markdown]
# <a href="https://colab.research.google.com/github/bonareri/disaster-impact-analysis/blob/main/Disaster_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# USGS Earthquake API (Last 30 Days, Magnitude > 4.5)
url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/4.5_month.csv"

# Load data into a DataFrame
earthquake_data = pd.read_csv(url)

# Display the first few rows
earthquake_data.head()
# Out:
#                        time  latitude  longitude    depth  mag magType   nst  \
# 0  2025-02-16T23:25:52.600Z  -30.1236   -71.3240   65.358  4.6      mb  39.0
# 1  2025-02-16T21:00:57.096Z  -19.4481   -69.6777  115.950  4.7      mb  39.0
# 2  2025-02-16T20:56:03.747Z    1.8736    98.9713  131.106  4.6      mb  46.0
# 3  2025-02-16T20:49:58.501Z    3.9857   143.7221   10.000  4.6      mb  37.0
# 4  2025-02-16T20:47:31.133Z   13.9448   -92.3610   35.000  4.9     mww  65.0
#
#      gap   dmin   rms  ...                   updated  \
# 0  123.0  0.217  0.76  ...  2025-02-17T00:45:34.712Z
# 1  112.0  0.506  0.82  ...  2025-02-16T23:41:00.461Z
# 2  180.0  2.717  0.55  ...  2025-02-16T21:25:10.040Z
# 3  119.0  7.009  0.74  ...  2025-02-16T21:11:30.040Z
# 4  160.0  0.991  1.07  ...  2025-02-17T00:02:14.792Z
#
#                                    place        type horizontalError  \
# 0             18 km S of Coquimbo, Chile  earthquake            3.94
# ...

# %%
#rename dataset
df = earthquake_data
